# %%
import requests
from bs4 import BeautifulSoup
url="https://stackoverflow.com/questions?sort=MostVotes&edited=true"
page=requests.get(url)
soup=BeautifulSoup(page.content,'html5lib')
soup
# Out:
# <!DOCTYPE html>
# <html class="html__responsive html__fixed-top-bar"><head>
#
#         <title>Highest Voted Questions - Stack Overflow</title>
#         <link href="https://cdn.sstatic.net/Sites/stackoverflow/Img/favicon.ico?v=ec617d715196" rel="shortcut icon"/>
#         <link href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a" rel="apple-touch-icon"/>
#         <link href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a" rel="image_src"/>
#         <link href="/opensearch.xml" rel="search" title="Stack Overflow" type="application/opensearchdescription+xml"/>
#         <meta content="width=device-width, height=device-height, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
#         <meta content="website" property="og:type"/>
#         <meta content="https://stackoverflow.com/questions?sort=MostVotes&amp;edited=true" property="og:url"/>
# ...

# %%
question_answer=soup.find_all(class_="question-summary")
len(question_answer)
# Out:
# 50

# %%
first=all_question[0]
first
# Out:
# <a class="question-hyperlink" href="/questions/11227809/why-is-processing-a-sorted-array-faster-than-processing-an-unsorted-array">Why is processing a sorted array faster than processing an unsorted array?</a>

# %%
f_question=first.find(class_="question-hyperlink").get_text().strip()
f_question
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-7e008ebcf29e> in <module>
# ----> 1 f_question=first.find(class_="question-hyperlink").get_text().strip()
#       2 f_question
#
# AttributeError: 'NoneType' object has no attribute 'get_text'
